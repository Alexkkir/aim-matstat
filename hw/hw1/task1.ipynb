# %% [markdown]
# Note that this notebook was automatically generated from an RDocumentation page. It depends on the package and the example code whether this code will run without errors. You may need to edit the code to make things work.

# %%
if(!require('jmuOutlier')) {
    install.packages('jmuOutlier')
    library('jmuOutlier')
}
# Out:
# Loading required package: jmuOutlier
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘jmuOutlier’”
# Retrieving 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/jmuOutlier_2.2.tar.gz' ...
# 	OK [downloaded 146.9 Kb in 0.4 secs]
# Installing jmuOutlier [2.2] ...
# 	OK [installed binary]
# Moving jmuOutlier [2.2] into the cache ...
# 	OK [moved to cache in 0.33 milliseconds]

# %%
# install.packages('jmuOutlier')
# library('jmuOutlier')
mu=2
sigma=2
M=100
n=999
res=matrix(data=NA, nrow=M, ncol=2)
for (k in 1:M) {
    x = rlaplace(n, mu, sigma)
    res[k, 1] = median(x)
    m1 = mean(x)
    m2 = mean(x^2)
    res[k, 2] = m1
}
boxplot(res)
# Out:
# plot without title

# %%
# install.packages('jmuOutlier')
# library('jmuOutlier')
mu=2
sigma=2
M=100
n=999
res=matrix(data=NA, nrow=M, ncol=2)
for (k in 1:M) {
    res[k, 1] = mean(abs(x - median(x)))
    m1 = mean(x)
    m2 = mean(x^2)
    res[k, 2] = sqrt(m2 - m1^2)
}
boxplot(res)
# Out:
# plot without title
